# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from time import sleep
import os
import pyeeg
import warnings
import pywt
import statistics
import scipy
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning) 
# %matplotlib notebook

# %%
dirB="/Users/Tiyas Dey/Downloads/EEG Epilepsy/O/"
tempB = []
for file in os.listdir(dirB):
    fl = dirB + file
    tempB.append(fl)
tempB = sorted(tempB)    # class: 1     val:  -1

dirC="/Users/Tiyas Dey/Downloads/EEG Epilepsy/N/"
tempC = []
for file in os.listdir(dirC):
    fl = dirC + file
    tempC.append(fl)
tempC = sorted(tempC)   # class:2       val: 0
    
dirE="/Users/Tiyas Dey/Downloads/EEG Epilepsy/S/"
tempE = []
for file in os.listdir(dirE):
    fl = dirE + file
    tempE.append(fl)
tempE = sorted(tempE) # class: 3        val: 1

# %%
tb = []
st = 'B'
for i in range(len(tempB)):
    file = open(tempB[i],"r")
    x = file.readlines()
    eeg = []
    for j in range(0,len(x)-1):
        eeg.append(float(x[j].strip('\n')))
    d = pd.DataFrame(data = eeg, columns=[st+str(i)])
    tb.append(d)
    
tc = []
st = 'C'
for i in range(len(tempC)):
    file = open(tempC[i],"r")
    x = file.readlines()
    eeg = []
    for j in range(0,len(x)-1):
        eeg.append(float(x[j].strip('\n')))
    d = pd.DataFrame(data = eeg, columns=[st+str(i)])
    tc.append(d)
    
te = []
st = 'E'
for i in range(len(tempE)):
    file = open(tempE[i],"r")
    x = file.readlines()
    eeg = []
    for j in range(0,len(x)-1):
        eeg.append(float(x[j].strip('\n')))
    d = pd.DataFrame(data = eeg, columns=[st+str(i)])
    te.append(d)

# %%
def table(table):
    big_table = None
    for ta in table:
        big_table = pd.concat([big_table, ta], axis = 1)
    return big_table

# %%
bigB = table(tb)
bigC = table(tc)
bigE = table(te)
headB = list(bigB.columns.values)
headC = list(bigC.columns.values)
headE = list(bigE.columns.values)

# %%
def features(arraya):
    from statistics import mean
    from scipy import stats
    m1 = max(arraya)
    m2 = min(arraya)
    meaan = mean(arraya)
    sd = statistics.stdev(arraya)
    v = sd*sd
    md = statistics.median(arraya)
    s = stats.skew(arraya)
    DFA = pyeeg.dfa(arraya)
    SVD_Entropy = pyeeg.svd_entropy(arraya,4,10)
    
    return (m1,m2,meaan,sd,v,md,s,DFA,SVD_Entropy)

# %%
from pywt import wavedec

#for i in range(len(headB)):
maximum = []
minimum = []
mean = []
deviation = []
variance = []
median = []
skew = []
dfa = []
entropy =[]
Class = []
for i in range(len(headB)):
    arr = []  
    for j in range(4096):
        arr.append(bigB[headB[i]].loc[j])
    coeffs = wavedec(arr, 'db4', level=4)
    delta, theta, alpha, beta, gamma = coeffs
    ga = features(gamma)
    maximum.append(ga[0])
    minimum.append(ga[1])
    mean.append(ga[2])
    deviation.append(ga[3])
    variance.append(ga[4])
    median.append(ga[5])
    skew.append(ga[6])
    dfa.append(ga[7])
    entropy.append(ga[8])
    Class.append(1)
m = pd.DataFrame(data = maximum, columns = ["Maximum"])
mm = pd.DataFrame(data = minimum, columns = ["Minimum"])
mn = pd.DataFrame(data = mean, columns = ["Mean"])
dd = pd.DataFrame(data = deviation, columns = ["Std Deviation"])
vv = pd.DataFrame(data = variance, columns = ["Variance"])
me = pd.DataFrame(data = median, columns = ["Median"])
sk = pd.DataFrame(data = skew, columns = ["Skew"])
df = pd.DataFrame(data = dfa, columns = ["DFA"])
en = pd.DataFrame(data = entropy, columns = ["Entropy"])
cl = pd.DataFrame(data = Class, columns = ["Class"])
g = pd.concat([m,mm,mn,dd,vv,me,sk,df,en,cl],axis = 1)


maximum = []
minimum = []
mean = []
deviation = []
variance = []
median = []
skew = []
dfa = []
entropy =[]
Class = []
for i in range(len(headB)):
    arr = []  
    for j in range(4096):
        arr.append(bigB[headB[i]].loc[j])
    coeffs = wavedec(arr, 'db4', level=4)
    delta, theta, alpha, beta, gamma = coeffs
    ga = features(beta)
    maximum.append(ga[0])
    minimum.append(ga[1])
    mean.append(ga[2])
    deviation.append(ga[3])
    variance.append(ga[4])
    median.append(ga[5])
    skew.append(ga[6])
    dfa.append(ga[7])
    entropy.append(ga[8])
    Class.append(1)
m = pd.DataFrame(data = maximum, columns = ["Maximum"])
mm = pd.DataFrame(data = minimum, columns = ["Minimum"])
mn = pd.DataFrame(data = mean, columns = ["Mean"])
dd = pd.DataFrame(data = deviation, columns = ["Std Deviation"])
vv = pd.DataFrame(data = variance, columns = ["Variance"])
me = pd.DataFrame(data = median, columns = ["Median"])
sk = pd.DataFrame(data = skew, columns = ["Skew"])
df = pd.DataFrame(data = dfa, columns = ["DFA"])
en = pd.DataFrame(data = entropy, columns = ["Entropy"])
cl = pd.DataFrame(data = Class, columns = ["Class"])

b = pd.concat([m,mm,mn,dd,vv,me,sk,df,en,cl],axis = 1)


maximum = []
minimum = []
mean = []
deviation = []
variance = []
median = []
skew = []
dfa = []
entropy =[]
Class = []
for i in range(len(headB)):
    arr = []  
    for j in range(4096):
        arr.append(bigB[headB[i]].loc[j])
    coeffs = wavedec(arr, 'db4', level=4)
    delta, theta, alpha, beta, gamma = coeffs
    ga = features(alpha)
    maximum.append(ga[0])
    minimum.append(ga[1])
    mean.append(ga[2])
    deviation.append(ga[3])
    variance.append(ga[4])
    median.append(ga[5])
    skew.append(ga[6])
    dfa.append(ga[7])
    entropy.append(ga[8])
    Class.append(1)
m = pd.DataFrame(data = maximum, columns = ["Maximum"])
mm = pd.DataFrame(data = minimum, columns = ["Minimum"])
mn = pd.DataFrame(data = mean, columns = ["Mean"])
dd = pd.DataFrame(data = deviation, columns = ["Std Deviation"])
vv = pd.DataFrame(data = variance, columns = ["Variance"])
me = pd.DataFrame(data = median, columns = ["Median"])
sk = pd.DataFrame(data = skew, columns = ["Skew"])
df = pd.DataFrame(data = dfa, columns = ["DFA"])
en = pd.DataFrame(data = entropy, columns = ["Entropy"])
cl = pd.DataFrame(data = Class, columns = ["Class"])

a = pd.concat([m,mm,mn,dd,vv,me,sk,df,en,cl],axis = 1)


maximum = []
minimum = []
mean = []
deviation = []
variance = []
median = []
skew = []
dfa = []
entropy =[]
Class = []
for i in range(len(headB)):
    arr = []  
    for j in range(4096):
        arr.append(bigB[headB[i]].loc[j])
    coeffs = wavedec(arr, 'db4', level=4)
    delta, theta, alpha, beta, gamma = coeffs
    ga = features(theta)
    maximum.append(ga[0])
    minimum.append(ga[1])
    mean.append(ga[2])
    deviation.append(ga[3])
    variance.append(ga[4])
    median.append(ga[5])
    skew.append(ga[6])
    dfa.append(ga[7])
    entropy.append(ga[8])
    Class.append(1);
m = pd.DataFrame(data = maximum, columns = ["Maximum"])
mm = pd.DataFrame(data = minimum, columns = ["Minimum"])
mn = pd.DataFrame(data = mean, columns = ["Mean"])
dd = pd.DataFrame(data = deviation, columns = ["Std Deviation"])
vv = pd.DataFrame(data = variance, columns = ["Variance"])
me = pd.DataFrame(data = median, columns = ["Median"])
sk = pd.DataFrame(data = skew, columns = ["Skew"])
df = pd.DataFrame(data = dfa, columns = ["DFA"])
en = pd.DataFrame(data = entropy, columns = ["Entropy"])
cl = pd.DataFrame(data = Class, columns = ["Class"])

t = pd.concat([m,mm,mn,dd,vv,me,sk,df,en,cl],axis = 1)


maximum = []
minimum = []
mean = []
deviation = []
variance = []
median = []
skew = []
dfa = []
entropy =[]
Class = []
for i in range(len(headB)):
    arr = []  
    for j in range(4096):
        arr.append(bigB[headB[i]].loc[j])
    coeffs = wavedec(arr, 'db4', level=4)
    delta, theta, alpha, beta, gamma = coeffs
    ga = features(delta)
    maximum.append(ga[0])
    minimum.append(ga[1])
    mean.append(ga[2])
    deviation.append(ga[3])
    variance.append(ga[4])
    median.append(ga[5])
    skew.append(ga[6])
    dfa.append(ga[7])
    entropy.append(ga[8])
    Class.append(1)
m = pd.DataFrame(data = maximum, columns = ["Maximum"])
mm = pd.DataFrame(data = minimum, columns = ["Minimum"])
mn = pd.DataFrame(data = mean, columns = ["Mean"])
dd = pd.DataFrame(data = deviation, columns = ["Std Deviation"])
vv = pd.DataFrame(data = variance, columns = ["Variance"])
me = pd.DataFrame(data = median, columns = ["Median"])
sk = pd.DataFrame(data = skew, columns = ["Skew"])
df = pd.DataFrame(data = dfa, columns = ["DFA"])
en = pd.DataFrame(data = entropy, columns = ["Entropy"])
cl = pd.DataFrame(data = Class, columns = ["Class"])

d = pd.concat([m,mm,mn,dd,vv,me,sk,df,en,cl],axis = 1)

SetB = pd.concat([g,b,a,t,d], keys = ["Gamma", "Beta", "Alpha", "Theta", "Delta"])
# Out:
# C:\Users\Tiyas Dey\Downloads\Anaconda\lib\site-packages\pyeeg-0.4.4-py3.7.egg\pyeeg\detrended_fluctuation_analysis.py:125: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
# C:\Users\Tiyas Dey\Downloads\Anaconda\lib\site-packages\pyeeg-0.4.4-py3.7.egg\pyeeg\detrended_fluctuation_analysis.py:131: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.

# %%
SetB2 = pd.concat([g,b,a,t,d], ignore_index = True)

# %%
from pywt import wavedec

#for i in range(len(headB)):
maximum = []
minimum = []
mean = []
deviation = []
variance = []
median = []
skew = []
dfa = []
entropy =[]
Class = []
for i in range(len(headC)):
    arr = []  
    for j in range(4096):
        arr.append(bigC[headC[i]].loc[j])
    coeffs = wavedec(arr, 'db4', level=4)
    delta, theta, alpha, beta, gamma = coeffs
    ga = features(gamma)
    maximum.append(ga[0])
    minimum.append(ga[1])
    mean.append(ga[2])
    deviation.append(ga[3])
    variance.append(ga[4])
    median.append(ga[5])
    skew.append(ga[6])
    dfa.append(ga[7])
    entropy.append(ga[8])
    Class.append(0)
m = pd.DataFrame(data = maximum, columns = ["Maximum"])
mm = pd.DataFrame(data = minimum, columns = ["Minimum"])
mn = pd.DataFrame(data = mean, columns = ["Mean"])
dd = pd.DataFrame(data = deviation, columns = ["Std Deviation"])
vv = pd.DataFrame(data = variance, columns = ["Variance"])
me = pd.DataFrame(data = median, columns = ["Median"])
sk = pd.DataFrame(data = skew, columns = ["Skew"])
df = pd.DataFrame(data = dfa, columns = ["DFA"])
en = pd.DataFrame(data = entropy, columns = ["Entropy"])
cl = pd.DataFrame(data = Class, columns = ["Class"])
g = pd.concat([m,mm,mn,dd,vv,me,sk,df,en,cl],axis = 1)


maximum = []
minimum = []
mean = []
deviation = []
variance = []
median = []
skew = []
dfa = []
entropy =[]
Class = []
for i in range(len(headC)):
    arr = []  
    for j in range(4096):
        arr.append(bigC[headC[i]].loc[j])
    coeffs = wavedec(arr, 'db4', level=4)
    delta, theta, alpha, beta, gamma = coeffs
    ga = features(beta)
    maximum.append(ga[0])
    minimum.append(ga[1])
    mean.append(ga[2])
    deviation.append(ga[3])
    variance.append(ga[4])
    median.append(ga[5])
    skew.append(ga[6])
    dfa.append(ga[7])
    entropy.append(ga[8])
    Class.append(0)
m = pd.DataFrame(data = maximum, columns = ["Maximum"])
mm = pd.DataFrame(data = minimum, columns = ["Minimum"])
mn = pd.DataFrame(data = mean, columns = ["Mean"])
dd = pd.DataFrame(data = deviation, columns = ["Std Deviation"])
vv = pd.DataFrame(data = variance, columns = ["Variance"])
me = pd.DataFrame(data = median, columns = ["Median"])
sk = pd.DataFrame(data = skew, columns = ["Skew"])
df = pd.DataFrame(data = dfa, columns = ["DFA"])
en = pd.DataFrame(data = entropy, columns = ["Entropy"])
cl = pd.DataFrame(data = Class, columns = ["Class"])
b = pd.concat([m,mm,mn,dd,vv,me,sk,df,en,cl],axis = 1)


maximum = []
minimum = []
mean = []
deviation = []
variance = []
median = []
skew = []
dfa = []
entropy =[]
Class = []
for i in range(len(headB)):
    arr = []  
    for j in range(4096):
        arr.append(bigC[headC[i]].loc[j])
    coeffs = wavedec(arr, 'db4', level=4)
    delta, theta, alpha, beta, gamma = coeffs
    ga = features(alpha)
    maximum.append(ga[0])
    minimum.append(ga[1])
    mean.append(ga[2])
    deviation.append(ga[3])
    variance.append(ga[4])
    median.append(ga[5])
    skew.append(ga[6])
    dfa.append(ga[7])
    entropy.append(ga[8])
    Class.append(0)
m = pd.DataFrame(data = maximum, columns = ["Maximum"])
mm = pd.DataFrame(data = minimum, columns = ["Minimum"])
mn = pd.DataFrame(data = mean, columns = ["Mean"])
dd = pd.DataFrame(data = deviation, columns = ["Std Deviation"])
vv = pd.DataFrame(data = variance, columns = ["Variance"])
me = pd.DataFrame(data = median, columns = ["Median"])
sk = pd.DataFrame(data = skew, columns = ["Skew"])
df = pd.DataFrame(data = dfa, columns = ["DFA"])
en = pd.DataFrame(data = entropy, columns = ["Entropy"])
cl = pd.DataFrame(data = Class, columns = ["Class"])
a = pd.concat([m,mm,mn,dd,vv,me,sk,df,en,cl],axis = 1)


maximum = []
minimum = []
mean = []
deviation = []
variance = []
median = []
skew = []
dfa = []
entropy =[]
Class = []
for i in range(len(headC)):
    arr = []  
    for j in range(4096):
        arr.append(bigC[headC[i]].loc[j])
    coeffs = wavedec(arr, 'db4', level=4)
    delta, theta, alpha, beta, gamma = coeffs
    ga = features(theta)
    maximum.append(ga[0])
    minimum.append(ga[1])
    mean.append(ga[2])
    deviation.append(ga[3])
    variance.append(ga[4])
    median.append(ga[5])
    skew.append(ga[6])
    dfa.append(ga[7])
    entropy.append(ga[8])
    Class.append(0)
m = pd.DataFrame(data = maximum, columns = ["Maximum"])
mm = pd.DataFrame(data = minimum, columns = ["Minimum"])
mn = pd.DataFrame(data = mean, columns = ["Mean"])
dd = pd.DataFrame(data = deviation, columns = ["Std Deviation"])
vv = pd.DataFrame(data = variance, columns = ["Variance"])
me = pd.DataFrame(data = median, columns = ["Median"])
sk = pd.DataFrame(data = skew, columns = ["Skew"])
df = pd.DataFrame(data = dfa, columns = ["DFA"])
en = pd.DataFrame(data = entropy, columns = ["Entropy"])
cl = pd.DataFrame(data = Class, columns = ["Class"])
t = pd.concat([m,mm,mn,dd,vv,me,sk,df,en,cl],axis = 1)


maximum = []
minimum = []
mean = []
deviation = []
variance = []
median = []
skew = []
dfa = []
entropy =[]
Class = []
for i in range(len(headC)):
    arr = []  
    for j in range(4096):
        arr.append(bigC[headC[i]].loc[j])
    coeffs = wavedec(arr, 'db4', level=4)
    delta, theta, alpha, beta, gamma = coeffs
    ga = features(delta)
    maximum.append(ga[0])
    minimum.append(ga[1])
    mean.append(ga[2])
    deviation.append(ga[3])
    variance.append(ga[4])
    median.append(ga[5])
    skew.append(ga[6])
    dfa.append(ga[7])
    entropy.append(ga[8])
    Class.append(0)
m = pd.DataFrame(data = maximum, columns = ["Maximum"])
mm = pd.DataFrame(data = minimum, columns = ["Minimum"])
mn = pd.DataFrame(data = mean, columns = ["Mean"])
dd = pd.DataFrame(data = deviation, columns = ["Std Deviation"])
vv = pd.DataFrame(data = variance, columns = ["Variance"])
me = pd.DataFrame(data = median, columns = ["Median"])
sk = pd.DataFrame(data = skew, columns = ["Skew"])
df = pd.DataFrame(data = dfa, columns = ["DFA"])
en = pd.DataFrame(data = entropy, columns = ["Entropy"])
cl = pd.DataFrame(data = Class, columns = ["Class"])
d = pd.concat([m,mm,mn,dd,vv,me,sk,df,en,cl],axis = 1)

SetC = pd.concat([g,b,a,t,d], keys = ["Gamma", "Beta", "Alpha", "Theta", "Delta"])

# %%
SetC2 = pd.concat([g,b,a,t,d], ignore_index = True)

# %%
from pywt import wavedec

#for i in range(len(headB)):
maximum = []
minimum = []
mean = []
deviation = []
variance = []
median = []
skew = []
dfa = []
entropy =[]
Class = []
for i in range(len(headE)):
    arr = []  
    for j in range(4096):
        arr.append(bigE[headE[i]].loc[j])
    coeffs = wavedec(arr, 'db4', level=4)
    delta, theta, alpha, beta, gamma = coeffs
    ga = features(gamma)
    maximum.append(ga[0])
    minimum.append(ga[1])
    mean.append(ga[2])
    deviation.append(ga[3])
    variance.append(ga[4])
    median.append(ga[5])
    skew.append(ga[6])
    dfa.append(ga[7])
    entropy.append(ga[8])
    Class.append(-1)
m = pd.DataFrame(data = maximum, columns = ["Maximum"])
mm = pd.DataFrame(data = minimum, columns = ["Minimum"])
mn = pd.DataFrame(data = mean, columns = ["Mean"])
dd = pd.DataFrame(data = deviation, columns = ["Std Deviation"])
vv = pd.DataFrame(data = variance, columns = ["Variance"])
me = pd.DataFrame(data = median, columns = ["Median"])
sk = pd.DataFrame(data = skew, columns = ["Skew"])
df = pd.DataFrame(data = dfa, columns = ["DFA"])
en = pd.DataFrame(data = entropy, columns = ["Entropy"])
cl = pd.DataFrame(data = Class, columns = ["Class"])
g = pd.concat([m,mm,mn,dd,vv,me,sk,df,en,cl],axis = 1)


maximum = []
minimum = []
mean = []
deviation = []
variance = []
median = []
skew = []
dfa = []
entropy =[]
Class = []
for i in range(len(headE)):
    arr = []  
    for j in range(4096):
        arr.append(bigE[headE[0]].loc[j])
    coeffs = wavedec(arr, 'db4', level=4)
    delta, theta, alpha, beta, gamma = coeffs
    ga = features(beta)
    maximum.append(ga[0])
    minimum.append(ga[1])
    mean.append(ga[2])
    deviation.append(ga[3])
    variance.append(ga[4])
    median.append(ga[5])
    skew.append(ga[6])
    dfa.append(ga[7])
    entropy.append(ga[8])
    Class.append(-1)
m = pd.DataFrame(data = maximum, columns = ["Maximum"])
mm = pd.DataFrame(data = minimum, columns = ["Minimum"])
mn = pd.DataFrame(data = mean, columns = ["Mean"])
dd = pd.DataFrame(data = deviation, columns = ["Std Deviation"])
vv = pd.DataFrame(data = variance, columns = ["Variance"])
me = pd.DataFrame(data = median, columns = ["Median"])
sk = pd.DataFrame(data = skew, columns = ["Skew"])
df = pd.DataFrame(data = dfa, columns = ["DFA"])
en = pd.DataFrame(data = entropy, columns = ["Entropy"])
cl = pd.DataFrame(data = Class, columns = ["Class"])
b = pd.concat([m,mm,mn,dd,vv,me,sk,df,en,cl],axis = 1)


maximum = []
minimum = []
mean = []
deviation = []
variance = []
median = []
skew = []
dfa = []
entropy =[]
Class = []
for i in range(len(headE)):
    arr = []  
    for j in range(4096):
        arr.append(bigE[headE[i]].loc[j])
    coeffs = wavedec(arr, 'db4', level=4)
    delta, theta, alpha, beta, gamma = coeffs
    ga = features(alpha)
    maximum.append(ga[0])
    minimum.append(ga[1])
    mean.append(ga[2])
    deviation.append(ga[3])
    variance.append(ga[4])
    median.append(ga[5])
    skew.append(ga[6])
    dfa.append(ga[7])
    entropy.append(ga[8])
    Class.append(-1)
m = pd.DataFrame(data = maximum, columns = ["Maximum"])
mm = pd.DataFrame(data = minimum, columns = ["Minimum"])
mn = pd.DataFrame(data = mean, columns = ["Mean"])
dd = pd.DataFrame(data = deviation, columns = ["Std Deviation"])
vv = pd.DataFrame(data = variance, columns = ["Variance"])
me = pd.DataFrame(data = median, columns = ["Median"])
sk = pd.DataFrame(data = skew, columns = ["Skew"])
df = pd.DataFrame(data = dfa, columns = ["DFA"])
en = pd.DataFrame(data = entropy, columns = ["Entropy"])
cl = pd.DataFrame(data = Class, columns = ["Class"])
a = pd.concat([m,mm,mn,dd,vv,me,sk,df,en,cl],axis = 1)


maximum = []
minimum = []
mean = []
deviation = []
variance = []
median = []
skew = []
dfa = []
entropy =[]
Class = []
for i in range(len(headE)):
    arr = []  
    for j in range(4096):
        arr.append(bigE[headE[i]].loc[j])
    coeffs = wavedec(arr, 'db4', level=4)
    delta, theta, alpha, beta, gamma = coeffs
    ga = features(theta)
    maximum.append(ga[0])
    minimum.append(ga[1])
    mean.append(ga[2])
    deviation.append(ga[3])
    variance.append(ga[4])
    median.append(ga[5])
    skew.append(ga[6])
    dfa.append(ga[7])
    entropy.append(ga[8])
    Class.append(-1)
m = pd.DataFrame(data = maximum, columns = ["Maximum"])
mm = pd.DataFrame(data = minimum, columns = ["Minimum"])
mn = pd.DataFrame(data = mean, columns = ["Mean"])
dd = pd.DataFrame(data = deviation, columns = ["Std Deviation"])
vv = pd.DataFrame(data = variance, columns = ["Variance"])
me = pd.DataFrame(data = median, columns = ["Median"])
sk = pd.DataFrame(data = skew, columns = ["Skew"])
df = pd.DataFrame(data = dfa, columns = ["DFA"])
en = pd.DataFrame(data = entropy, columns = ["Entropy"])
cl = pd.DataFrame(data = Class, columns = ["Class"])
t = pd.concat([m,mm,mn,dd,vv,me,sk,df,en,cl],axis = 1)


maximum = []
minimum = []
mean = []
deviation = []
variance = []
median = []
skew = []
dfa = []
entropy =[]
Class = []
for i in range(len(headE)):
    arr = []  
    for j in range(4096):
        arr.append(bigE[headE[i]].loc[j])
    coeffs = wavedec(arr, 'db4', level=4)
    delta, theta, alpha, beta, gamma = coeffs
    ga = features(delta)
    maximum.append(ga[0])
    minimum.append(ga[1])
    mean.append(ga[2])
    deviation.append(ga[3])
    variance.append(ga[4])
    median.append(ga[5])
    skew.append(ga[6])
    dfa.append(ga[7])
    entropy.append(ga[8])
    Class.append(-1)
m = pd.DataFrame(data = maximum, columns = ["Maximum"])
mm = pd.DataFrame(data = minimum, columns = ["Minimum"])
mn = pd.DataFrame(data = mean, columns = ["Mean"])
dd = pd.DataFrame(data = deviation, columns = ["Std Deviation"])
vv = pd.DataFrame(data = variance, columns = ["Variance"])
me = pd.DataFrame(data = median, columns = ["Median"])
sk = pd.DataFrame(data = skew, columns = ["Skew"])
df = pd.DataFrame(data = dfa, columns = ["DFA"])
en = pd.DataFrame(data = entropy, columns = ["Entropy"])
cl = pd.DataFrame(data = Class, columns = ["Class"])
d = pd.concat([m,mm,mn,dd,vv,me,sk,df,en,cl],axis = 1)

SetE = pd.concat([g,b,a,t,d], keys = ["Gamma", "Beta", "Alpha", "Theta", "Delta"])

# %%
SetE2 = pd.concat([g,b,a,t,d], ignore_index = True)

# %%
TotalDataset = pd.concat([SetB,SetC,SetE], keys = ["Set B", "Set C", "Set E"])

# %%
TotalDataset2 = pd.concat([SetB2,SetC2,SetE2],ignore_index = True)

# %%
TotalDataset2[400:1100:50]
# Out:
#          Maximum     Minimum        Mean  Std Deviation      Variance  \
# 400   723.147702 -355.817959   18.933005     144.767676  20957.680111
# 450  -114.371556 -526.963099 -297.606483      69.087457   4773.076648
# 500     9.168782   -6.810134    0.028464       2.002678      4.010720
# 550    31.546768  -28.930492   -0.060574       3.646465     13.296710
# 600    30.563350  -21.986468   -0.017434       7.126906     50.792792
# 650    76.569863 -124.305059   -0.023622      13.238440    175.256303
# 700    96.151913  -94.496397   -0.629831      26.735266    714.774430
# 750   189.805961 -424.446710   -1.139604      44.989946   2024.095269
# 800   234.366913 -195.141532    3.073811      77.583950   6019.269264
# 850   306.307603 -302.469971   -3.437052      98.937022   9788.534408
# 900   357.419220 -827.495974  -73.020693     175.239078  30708.734407
# 950   950.161247 -680.643632   54.436063     261.259649  68256.604420
# 1000  168.789933 -191.916342   -0.385762      29.680244    880.916900
# 1050   46.385507  -37.857089   -0.048963       8.416024     70.829465
#
#           Median      Skew       DFA   Entropy  Class
# 400     7.827092  0.586858  0.000000  2.294528      1
# 450  -294.291236 -0.041352  0.000000  1.538953      1
# 500     0.034977 -0.026332  0.452471  2.301415      0
# 550    -0.047409  0.243516  0.334610  2.290676      0
# 600    -0.035819  0.120072  0.162410  2.300139      0
# 650     0.163596 -0.735212  0.136886  2.299506      0
# 700    -0.832324  0.261487  0.809923  2.298103      0
# 750    -1.106296 -1.522828  0.995038  2.299451      0
# 800     2.228799  0.183766  0.000000  2.297408      0
# 850     4.959013 -0.128810  0.000000  2.298141      0
# 900   -71.180851 -0.431868  0.000000  2.286981      0
# 950    66.542185 -0.095053  0.000000  2.288437      0
# 1000    0.157482 -0.010717  0.349730  2.302144     -1
# 1050   -0.003159 -0.149170  0.332222  2.301254     -1

# %%
from sklearn.model_selection import train_test_split
X = TotalDataset2[["Maximum","Minimum","Mean","Std Deviation","Variance","Median","Skew","DFA","Entropy"]]
y = TotalDataset2[['Class']]
X = np.asarray(X)
y = np.asarray(y)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_moons, make_circles, make_classification
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

# %%
names = ["Nearest Neighbors", "Linear SVM", "RBF SVM", "Gaussian Process",
         "Decision Tree", "Random Forest", "Neural Net", "AdaBoost",
         "Naive Bayes", "QDA"]

# %%
classifiers = [
    KNeighborsClassifier(3),
    SVC(kernel="linear", C=0.025),
    SVC(gamma=2, C=1),
    GaussianProcessClassifier(1.0 * RBF(1.0), warm_start=True),
    DecisionTreeClassifier(max_depth=5),
    RandomForestClassifier(max_depth=5, n_estimators=10, max_features=1),
    MLPClassifier(alpha=1),
    AdaBoostClassifier(),
    GaussianNB(),
    QuadraticDiscriminantAnalysis()]

# %%
clf_score=[]
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    for name, clf in zip(names, classifiers):
        clf.fit(X_train, y_train)
        score = clf.score(X_test, y_test)
        clf_score.append([score,name])

# %%
clf_score
# Out:
# [[0.6828282828282828, 'Nearest Neighbors'],
#  [0.6505050505050505, 'Linear SVM'],
#  [0.4585858585858586, 'RBF SVM'],
#  [0.3575757575757576, 'Gaussian Process'],
#  [0.7494949494949495, 'Decision Tree'],
#  [0.7131313131313132, 'Random Forest'],
#  [0.5454545454545454, 'Neural Net'],
#  [0.7515151515151515, 'AdaBoost'],
#  [0.6626262626262627, 'Naive Bayes'],
#  [0.6606060606060606, 'QDA']]
